# %% [markdown]
# * Ray RLlib 노트북

# %% [markdown]
# 필요 패키지 삽입

# %%
import gymnasium as gym
import numpy as np
import pandas as pd

from horcrux_terrain_v1.envs import SandWorld
from horcrux_terrain_v1.envs import PlaneWorld
from horcrux_terrain_v1.envs import PlanePipeWorld

import ray
from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.algorithms.sac import SACConfig

from ray.tune.registry import register_env
# Out:
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %% [markdown]
# Ray 실행 (Warning 관련 무시 키워드)

# %%
ray.init(runtime_env={"env_vars": {"PYTHONWARNINGS": "ignore::DeprecationWarning"}})
# Out:
# 2024-10-08 01:21:44,825	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.12.5', ray_version='2.36.1', ray_commit='999f7668b65dbd208817b3671b441fd97fca755c')

# %% [markdown]
# Gym -> Rllib Env 등록

# %%
env_config = {
    "forward_reward_weight": 4,
    "side_cost_weight": 2,
    "unhealthy_max_steps": 75,
    "healthy_roll_range": (-45,45),
    "terminating_roll_range": (-85,85),
    "rotation_norm_cost_weight": 0.05,
    "termination_reward": 0,
}

# Sand
register_env("sand-v1", lambda config: SandWorld(forward_reward_weight=env_config["forward_reward_weight"], 
                                                 side_cost_weight=env_config["side_cost_weight"], 
                                                 unhealthy_max_steps=env_config["unhealthy_max_steps"], 
                                                 healthy_roll_range=env_config["healthy_roll_range"],
                                                 terminating_roll_range=env_config["terminating_roll_range"],
                                                 rotation_norm_cost_weight=env_config["rotation_norm_cost_weight"],
                                                 termination_reward=env_config["termination_reward"]))

# Plane
register_env("plane-v1", lambda config: PlaneWorld(forward_reward_weight=env_config["forward_reward_weight"], 
                                                 side_cost_weight=env_config["side_cost_weight"], 
                                                 unhealthy_max_steps=env_config["unhealthy_max_steps"], 
                                                 healthy_roll_range=env_config["healthy_roll_range"],
                                                 terminating_roll_range=env_config["terminating_roll_range"],
                                                 rotation_norm_cost_weight=env_config["rotation_norm_cost_weight"],
                                                 termination_reward=env_config["termination_reward"]))

# Pipe
register_env("pipe-v1", lambda config: PlanePipeWorld(forward_reward_weight=env_config["forward_reward_weight"], 
                                                 side_cost_weight=env_config["side_cost_weight"], 
                                                 unhealthy_max_steps=env_config["unhealthy_max_steps"], 
                                                 healthy_roll_range=env_config["healthy_roll_range"],
                                                 terminating_roll_range=env_config["terminating_roll_range"],
                                                 rotation_norm_cost_weight=env_config["rotation_norm_cost_weight"],
                                                 termination_reward=env_config["termination_reward"]))

# %% [markdown]
# 학습 알고리즘 설정

# %%
config = SACConfig()
# Activate new API stack. -> 구려서 안씀.
config.api_stack(
    enable_rl_module_and_learner=False,
    enable_env_runner_and_connector_v2=False,
)
# config.environment("sand-v1")
config.environment("pipe-v1")
config.framework("torch")
total_workers = 12
config.resources(num_gpus=1,num_cpus_per_worker=1, num_gpus_per_worker= 1/(total_workers+1))
config.rollouts(num_rollout_workers=total_workers)
config.training(
    gamma=0.9, 
    # kl_coeff=0.3, 
    replay_buffer_config = {
            "_enable_replay_buffer_api": True,
            "type": "MultiAgentPrioritizedReplayBuffer",
            "capacity": int(1e6),
            # If True prioritized replay buffer will be used.
            "prioritized_replay": False,
            "prioritized_replay_alpha": 0.6,
            "prioritized_replay_beta": 0.4,
            "prioritized_replay_eps": 1e-6,
            # Whether to compute priorities already on the remote worker side.
            "worker_side_prioritization": False,
        },

    # See model catalog for more options.
    # https://docs.ray.io/en/latest/rllib/rllib-models.html
    q_model_config = {
            "fcnet_hiddens": [512, 512, 512, 512, 512],
            "fcnet_activation": "relu",
            "post_fcnet_hiddens": [],
            "post_fcnet_activation": None,
            "custom_model": None,  # Use this to define custom Q-model(s).
            "custom_model_config": {},
        },
    policy_model_config = {
            "fcnet_hiddens": [512, 512, 512, 512, 512],
            "fcnet_activation": "relu",
            "post_fcnet_hiddens": [],
            "post_fcnet_activation": None,
            "custom_model": None,  # Use this to define a custom policy model.
            "custom_model_config": {},
        },
    train_batch_size_per_learner = 8192,
    num_steps_sampled_before_learning_starts = 3000,

)
config.evaluation(evaluation_interval=100)

# # See model catalog for more options.
# # https://docs.ray.io/en/latest/rllib/rllib-models.html
# # config.model["fcnet_hiddens"] = [512, 512, 512, 512, 512]
# config.model["uses_new_env_runners"] = True
# config.model["fcnet_hiddens"] = [1024, 1024, 1024, 1024, 1024]
# config.model["use_lstm"] = True
# # config.model["lstm_cell_size"] = 2048
# config.model["lstm_cell_size"] = 4096
# config.model["max_seq_len"] = 200
# config.model["lstm_use_prev_action"] = True

algo = config.build()
# Out:
# 2024-10-08 01:22:09,733	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.resources(num_cpus_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_cpus_per_env_runner)` instead. This will raise an error in the future!
# 2024-10-08 01:22:09,733	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.resources(num_gpus_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_gpus_per_env_runner)` instead. This will raise an error in the future!
# 2024-10-08 01:22:09,733	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# 2024-10-08 01:22:09,733	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\ray\rllib\algorithms\algorithm.py:555: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=38972) c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
# (pid=38972)   "cipher": algorithms.TripleDES,
# (pid=38972) c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
# (pid=38972)   "class": algorithms.Blowfish,
# (pid=38972) c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
# (pid=38972)   "class": algorithms.TripleDES,
# 2024-10-08 01:22:28,971	INFO trainable.py:161 -- Trainable.setup took 19.202 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-10-08 01:22:28,982	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %% [markdown]
# 혹시 이전 학습 결과를 로드할 경우

# %%
# algo = Algorithm.from_checkpoint("./agents/ModelV2_512x5_2048_v0924_2")

# %% [markdown]
# 학습 파라미터 재조정

# %%
# algo.get_config().training().num_sgd_iter

#Env runner 파라미터 보기.
# algo.env_runner.config["exploration_config"]
# algo.get_config().model

# algo.compute_single_action()
algo.get_policy().model

# %% [markdown]
# 학습 시작

# %%
from pprint import pprint

n_iter = 10000
save_iter = 0
save_name = "obstacle_512x5"

for i in range(n_iter):
    result = algo.train()
    print(f"{i:03d}th iteration done")
    # result.pop("config")
    # pprint(result)

    if i%500 == 0:
        checkpoint_dir = algo.save(save_name+"_"+str(save_iter))
        print(f"Checkpoint saved in directory {checkpoint_dir}")
        save_iter += 1

algo.save(save_name+str("_final"))
# Out:
# 2024-10-08 01:23:22,922	WARNING multi_agent_prioritized_replay_buffer.py:215 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# 000th iteration done
# Checkpoint saved in directory TrainingResult(checkpoint=Checkpoint(filesystem=local, path=obstacle_512x5_0), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {}, 'num_env_steps_sampled': 504, 'num_env_steps_trained': 0, 'num_agent_steps_sampled': 504, 'num_agent_steps_trained': 0}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 12, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 504, 'num_agent_steps_trained': 0, 'num_env_steps_sampled': 504, 'num_env_steps_trained': 0, 'num_env_steps_sampled_this_iter': 504, 'num_env_steps_trained_this_iter': 0, 'num_env_steps_sampled_throughput_per_sec': 501.12073597520197, 'num_env_steps_trained_throughput_per_sec': 0.0, 'timesteps_total': 504, 'num_env_steps_sampled_lifetime': 504, 'num_agent_steps_sampled_lifetime': 504, 'num_steps_trained_this_iter': 0, 'agent_timesteps_total': 504, 'timers': {'training_iteration_time_ms': 1005.746, 'restore_workers_time_ms': 0.0, 'training_step_time_ms': 18.258, 'sample_time_ms': 18.158}, 'counters': {'num_env_steps_sampled': 504, 'num_env_steps_trained': 0, 'num_agent_steps_sampled': 504, 'num_agent_steps_trained': 0}, 'done': False, 'training_iteration': 1, 'trial_id': 'default', 'date': '2024-10-08_01-23-23', 'timestamp': 1728318203, 'time_this_iter_s': 1.0057456493377686, 'time_total_s': 1.0057456493377686, 'pid': 25604, 'hostname': 'OMEN-45L', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradients': False, 'enable_rl_module_and_learner': False, 'enable_env_runner_and_connector_v2': False, 'env': 'pipe-v1', 'env_config': {}, 'observation_space': None, 'action_space': None, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, '_is_atari': None, 'disable_env_checking': False, 'env_task_fn': None, 'render_env': False, 'action_mask_key': 'action_mask', 'env_runner_cls': None, 'num_env_runners': 12, 'num_envs_per_env_runner': 1, 'num_cpus_per_env_runner': 1, 'num_gpus_per_env_runner': 0.07692307692307693, 'custom_resources_per_env_runner': {}, 'validate_env_runners_after_construction': True, 'sample_timeout_s': 60.0, '_env_to_module_connector': None, 'add_default_connectors_to_env_to_module_pipeline': True, '_module_to_env_connector': None, 'add_default_connectors_to_module_to_env_pipeline': True, 'episode_lookback_horizon': 1, 'rollout_fragment_length': 'auto', 'batch_mode': 'truncate_episodes', 'compress_observations': False, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'enable_tf1_exec_eagerly': False, 'sample_collector': <class 'ray.rllib.eva ...
# 001th iteration done
# 002th iteration done
# 003th iteration done
# 004th iteration done
# 2024-10-08 01:23:28,106	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# 005th iteration done
# 006th iteration done
# 007th iteration done
# 008th iteration done
# 009th iteration done
# 010th iteration done
# 011th iteration done
# 012th iteration done
# 013th iteration done
# 014th iteration done
# 015th iteration done
# 016th iteration done
# 017th iteration done
# 018th iteration done
# 019th iteration done
# 020th iteration done
# 021th iteration done
# 022th iteration done
# 023th iteration done
# 024th iteration done
# 025th iteration done
# 026th iteration done
# 027th iteration done
# 028th iteration done
# 029th iteration done
# 030th iteration done
# 031th iteration done
# 032th iteration done
# 033th iteration done
# 034th iteration done
# 035th iteration done
# 036th iteration done
# 037th iteration done
# 038th iteration done
# 039th iteration done
# 040th iteration done
# 041th iteration done
# 042th iteration done
# 043th iteration done
# 044th iteration done
# 045th iteration done
# 046th iteration done
# 047th iteration done
# 048th iteration done
# 049th iteration done
# 050th iteration done
# 051th iteration done
# 052th iteration done
# 053th iteration done
# 054th iteration done
# 055th iteration done
# 056th iteration done
# 057th iteration done
# 058th iteration done
# 059th iteration done
# 060th iteration done
# 061th iteration done
# 062th iteration done
# 063th iteration done
# 064th iteration done
# 065th iteration done
# 066th iteration done
# 067th iteration done
# 068th iteration done
# 069th iteration done
# 070th iteration done
# 071th iteration done
# 072th iteration done
# 073th iteration done
# 074th iteration done
# 075th iteration done
# 076th iteration done
# 077th iteration done
# 078th iteration done
# 079th iteration done
# 080th iteration done
# 081th iteration done
# 082th iteration done
# 083th iteration done
# 084th iteration done
# 085th iteration done
# 086th iteration done
# 087th iteration done
# 088th iteration done
# 089th iteration done
# 090th iteration done
# 091th iteration done
# 092th iteration done
# 093th iteration done
# 094th iteration done
# 095th iteration done
# 096th iteration done
# 097th iteration done
# 098th iteration done
# 2024-10-08 01:26:28,247	WARNING env_runner_v2.py:158 -- More than 6000 observations in 6000 env steps for episode 203033982024562438 are buffered in the sampler. If this is more than you expected, check that that you set a horizon on your environment correctly and that it terminates at some point. Note: In multi-agent environments, `rollout_fragment_length` sets the batch size based on (across-agents) environment steps, not the steps of individual agents, which can result in unexpectedly large batches.Also, you may be waiting for your Env to terminate (batch_mode=`complete_episodes`). Make sure it does at some point.
# 099th iteration done
# 100th iteration done
# 101th iteration done
# 102th iteration done
# 103th iteration done
# 104th iteration done
# 105th iteration done
# 106th iteration done
# 107th iteration done
# 108th iteration done
# 109th iteration done
# 110th iteration done
# 111th iteration done
# 112th iteration done
# 113th iteration done
# 114th iteration done
# 115th iteration done
# 116th iteration done
# 117th iteration done
# 118th iteration done
# 119th iteration done
# 120th iteration done
# 121th iteration done
# 122th iteration done
# 123th iteration done
# 124th iteration done
# 125th iteration done
# 126th iteration done
# 127th iteration done
# 128th iteration done
# 129th iteration done
# 130th iteration done
# 131th iteration done
# 132th iteration done
# 133th iteration done
# 134th iteration done
# 135th iteration done
# 136th iteration done
# 137th iteration done
# 138th iteration done
# 139th iteration done
# 140th iteration done
# 141th iteration done
# 142th iteration done
# 143th iteration done
# 144th iteration done
# 145th iteration done
# 146th iteration done
# 147th iteration done
# 148th iteration done
# 149th iteration done
# 150th iteration done
# 151th iteration done
# 152th iteration done
# 153th iteration done
# 154th iteration done
# 155th iteration done
# 156th iteration done
# 157th iteration done
# 158th iteration done
# 159th iteration done
# 160th iteration done
# 161th iteration done
# 162th iteration done
# 163th iteration done
# 164th iteration done
# 165th iteration done
# 166th iteration done
# 167th iteration done
# 168th iteration done
# 169th iteration done
# 170th iteration done
# 171th iteration done
# 172th iteration done
# 173th iteration done
# 174th iteration done
# 175th iteration done
# 176th iteration done
# 177th iteration done
# 178th iteration done
# 179th iteration done
# 180th iteration done
# 181th iteration done
# 182th iteration done
# 183th iteration done
# 184th iteration done
# 185th iteration done
# 186th iteration done
# 187th iteration done
# 188th iteration done
# 189th iteration done
# 190th iteration done
# 191th iteration done
# 192th iteration done
# 193th iteration done
# 194th iteration done
# 195th iteration done
# 196th iteration done
# 197th iteration done
# 198th iteration done
# 199th iteration done
# 200th iteration done
# 201th iteration done
# 202th iteration done
# 203th iteration done
# 204th iteration done
# 205th iteration done
# 206th iteration done
# 207th iteration done
# 208th iteration done
# 209th iteration done
# 210th iteration done
# 211th iteration done
# 212th iteration done
# 213th iteration done
# 214th iteration done
# 215th iteration done
# 216th iteration done
# 217th iteration done
# 218th iteration done
# 219th iteration done
# 220th iteration done
# 221th iteration done
# 222th iteration done
# 223th iteration done
# 224th iteration done
# 225th iteration done
# 226th iteration done
# 227th iteration done
# 228th iteration done
# 229th iteration done
# 230th iteration done
# 231th iteration done
# 232th iteration done
# 233th iteration done
# 234th iteration done
# 235th iteration done
# 236th iteration done
# 237th iteration done
# 238th iteration done
# 239th iteration done
# 240th iteration done
# 241th iteration done
# 242th iteration done
# 243th iteration done
# 244th iteration done
# 245th iteration done
# 246th iteration done
# 247th iteration done
# 248th iteration done
# 249th iteration done
# 250th iteration done
# 251th iteration done
# 252th iteration done
# 253th iteration done
# 254th iteration done
# 255th iteration done
# 256th iteration done
# 257th iteration done
# 258th iteration done
# 259th iteration done
# 260th iteration done
# 261th iteration done
# 262th iteration done
# 263th iteration done
# 264th iteration done
# 265th iteration done
# 266th iteration done
# 267th iteration done
# 268th iteration done
# 269th iteration done
# 270th iteration done
# 271th iteration done
# 272th iteration done
# 273th iteration done
# 274th iteration done
# 275th iteration done
# 276th iteration done
# 277th iteration done
# 278th iteration done
# 279th iteration done
# 280th iteration done
# 281th iteration done
# 282th iteration done
# 283th iteration done
# 284th iteration done
# 285th iteration done
# 286th iteration done
# 287th iteration done
# 288th iteration done
# 289th iteration done
# 290th iteration done
# 291th iteration done
# 292th iteration done
# 293th iteration done
# 294th iteration done
# 295th iteration done
# 296th iteration done
# 297th iteration done
# 298th iteration done
# 299th iteration done
# 300th iteration done
# 301th iteration done
# 302th iteration done
# 303th iteration done
# 304th iteration done
# 305th iteration done
# 306th iteration done
# 307th iteration done
# 308th iteration done
# 309th iteration done
# 310th iteration done
# 311th iteration done
# 312th iteration done
# 313th iteration done
# 314th iteration done
# 315th iteration done
# 316th iteration done
# 317th iteration done
# 318th iteration done
# 319th iteration done
# 320th iteration done
# 321th iteration done
# 322th iteration done
# 323th iteration done
# 324th iteration done
# 325th iteration done
# 326th iteration done
# 327th iteration done
# 328th iteration done
# 329th iteration done
# 330th iteration done
# 331th iteration done
# 332th iteration done
# 333th iteration done
# 334th iteration done
# 335th iteration done
# 336th iteration done
# 337th iteration done
# 338th iteration done
# 339th iteration done
# 340th iteration done
# 341th iteration done
# 342th iteration done
# 343th iteration done
# 344th iteration done
# 345th iteration done
# 346th iteration done
# 347th iteration done
# 348th iteration done
# 349th iteration done
# 350th iteration done
# 351th iteration done
# 352th iteration done
# 353th iteration done
# 354th iteration done
# 355th iteration done
# 356th iteration done
# 357th iteration done
# 358th iteration done
# 359th iteration done
# 360th iteration done
# 361th iteration done
# 362th iteration done
# 363th iteration done
# 364th iteration done
# 365th iteration done
# 366th iteration done
# 367th iteration done
# 368th iteration done
# 369th iteration done
# 370th iteration done
# 371th iteration done
# 372th iteration done
# 373th iteration done
# 374th iteration done
# 375th iteration done
# 376th iteration done
# 377th iteration done
# 378th iteration done
# 379th iteration done
# 380th iteration done
# 381th iteration done
# 382th iteration done
# 383th iteration done
# 384th iteration done
# 385th iteration done
# 386th iteration done
# 387th iteration done
# 388th iteration done
# 389th iteration done
# 390th iteration done
# 391th iteration done
# 392th iteration done
# 393th iteration done
# 394th iteration done
# 395th iteration done
# 396th iteration done
# 397th iteration done
# 398th iteration done
# 399th iteration done
# 400th iteration done
# 401th iteration done
# 402th iteration done
# 403th iteration done
# 404th iteration done
# 405th iteration done
# 406th iteration done
# 407th iteration done
# 408th iteration done
# 409th iteration done
# 410th iteration done
# 411th iteration done
# 412th iteration done
# 413th iteration done
# 414th iteration done
# 415th iteration done
# 416th iteration done
# 417th iteration done
# 418th iteration done
# 419th iteration done
# 420th iteration done
# 421th iteration done
# 422th iteration done
# 423th iteration done
# 424th iteration done
# 425th iteration done
# 426th iteration done
# 427th iteration done
# 428th iteration done
# 429th iteration done
# 430th iteration done
# 431th iteration done
# 432th iteration done
# 433th iteration done
# 434th iteration done
# 435th iteration done
# 436th iteration done
# 437th iteration done
# 438th iteration done
# 439th iteration done
# 440th iteration done
# 441th iteration done
# 442th iteration done
# 443th iteration done
# 444th iteration done
# 445th iteration done
# 446th iteration done
# 447th iteration done
# 448th iteration done
# 449th iteration done
# 450th iteration done
# 451th iteration done
# 452th iteration done
# 453th iteration done
# 454th iteration done
# 455th iteration done
# 456th iteration done
# 457th iteration done
# 458th iteration done
# 459th iteration done
# 460th iteration done
# 461th iteration done
# 462th iteration done
# 463th iteration done
# 464th iteration done
# 465th iteration done
# 466th iteration done
# 467th iteration done
# 468th iteration done
# 469th iteration done
# 470th iteration done
# 471th iteration done
# 472th iteration done
# 473th iteration done
# 474th iteration done
# 475th iteration done
# 476th iteration done
# 477th iteration done
# 478th iteration done
# 479th iteration done
# 480th iteration done
# 481th iteration done
# 482th iteration done
# 483th iteration done
# 484th iteration done
# 485th iteration done
# 486th iteration done
# 487th iteration done
# 488th iteration done
# 489th iteration done
# 490th iteration done
# 491th iteration done
# 492th iteration done
# 493th iteration done
# 494th iteration done
# 495th iteration done
# 496th iteration done
# 497th iteration done
# 498th iteration done
# 499th iteration done
# 500th iteration done
# Checkpoint saved in directory TrainingResult(checkpoint=Checkpoint(filesystem=local, path=obstacle_512x5_1), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {
#        0.1498642 , 0.5453682 , 2.2734327 , 1.1545572 , 1.0947924 ,
#        0.24779415, 0.740201  , 0.43424892, 0.42363644, 0.21264553,
#        0.2922144 , 0.69752693, 0.33252525, 1.247817  , 0.5411396 ,
#        0.6319065 , 0.28040504, 1.1617327 , 1.0984726 , 0.6550169 ,
#        0.23900604, 0.08255672, 0.76419926, 1.001749  , 0.445199  ,
#        1.2469759 , 0.58330345, 0.29469967, 1.4646912 , 0.30040932,
#        0.49543   , 0.6804352 , 1.1347914 , 0.20299149, 2.5337    ,
#        1.1439276 , 1.531189  , 0.812727  , 0.8385973 , 0.08432102,
#        0.8055401 , 0.48207092, 0.7632599 , 0.6045637 , 1.1286478 ,
#        1.2704697 , 0.10832024, 0.82647896, 0.9491625 , 1.153883  ,
#        0.05620098, 0.27057362, 0.7899208 , 0.2562294 , 0.8939676 ,
#        0.31761837, 0.87237835, 0.39708996, 0.44994164, 0.22600365,
#        0.41463566, 0.33531475, 0.7842579 , 0.4663124 , 0.6177788 ,
#        1.0269289 , 1.1776342 , 0.33517933, 0.25872326, 0.55123615,
#        0.4438877 , 0.6667166 , 0.59729385, 0.93417454, 0.12878609,
#        1.0758152 , 1.4318724 , 0.33143234, 0.40503693, 0.30440998,
#        0.38708687, 0.17438126, 0.1652298 , 0.48010826, 0.16674995,
#        0.55761814, 0.15035248, 0.32466316, 1.1677856 , 0.10509205,
#        0.396101  , 1.002264  , 0.18166924, 0.43066597, 0.06231308,
#        0.28227234, 0.4416561 , 0.46305752, 0.5752659 , 0.24292946,
#        1.080739  , 0.19819736, 0.33290195, 0.4408884 , 0.743927  ,
#        0.45704937], dtype=float32), 'mean_td_error': 0.595703661441803}}, 'num_env_steps_sampled': 56520, 'num_env_steps_trained': 1141760, 'num_agent_steps_sampled': 56520, 'num_agent_steps_trained': 1141760, 'last_target_update_ts': 56520, 'num_target_updates': 4460, 'num_env_steps_sampled_for_evaluation_this_iter': 57431}, 'env_runners': {'episode_reward_max': 226.00538271898725, 'episode_reward_min': 170.4963788648225, 'episode_reward_mean': 198.25088079190488, 'episode_len_mean': 3058.0, 'episode_media': {}, 'episodes_timesteps_total': 6116, 'policy_reward_min': {'default_policy': 170.4963788648225}, 'policy_reward_max': {'default_policy': 226.00538271898725}, 'policy_reward_mean': {'default_policy': 198.25088079190488}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [170.4963788648225, 226.00538271898725], 'episode_lengths': [3055, 3061], 'policy_default_policy_reward': [170.4963788648225, 226.00538271898725]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.8023128341445724, 'mean_inference_ms': 17.31133581608456, 'mean_action_processing_ms': 0.23874348666587014, 'mean_env_wait_ms': 2.412479049854428, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0, 'StateBufferConnector_ms': 0.0, 'ViewRequirementAgentConnector_ms': 0.0}, 'num_episodes': 0, 'episode_return_max': 226.00538271898725, 'episode_return_min': 170.4963788648225, 'episode_return_mean': 198.25088079190488, 'episodes_this_iter': 0}, 'num_healthy_workers': 12, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 56520, 'num_agent_steps_trained': 1141760, 'num_env_steps_sampled': 56520, 'num_env_steps_trained': 1141760, 'num_env_steps_sampled_this_iter': 108, 'num_env_steps_trained_this_iter': 2304, 'num_env_steps_sampled_throughput_per_sec': 64.80573537086717, 'num_env_steps_trained_throughput_per_sec': 1382.5223545784997, 'timesteps_total': 56520, 'num_env_steps_sampled_lifetime': 56520, 'num_agent_steps_sampled_lifetime': 56520, 'num_steps_trained_this_iter': 2304, 'agent_timesteps_total': 56520, 'timers': {'training_iteration_time_ms': 1700.403, 'restore_workers_time_ms': 0.0, 'training_step_time_ms': 185.23, 'sample_time_ms': 55.139, 'load_time_ms': 1.451, 'load_throughput': 176428.167, 'learn_time_ms': 19.414, 'learn_throughput': 13186.331, 'synch_weights_time_ms': 30.343, 'restore_eval_workers_time_ms': 0.0, 'evaluation_iteration_time_ms': 215351.012, 'evaluation_iteration_throughput': 273.016}, 'counters': {'num_env_steps_sampled': 56520, 'num_env_steps_trained': 1141760, 'num_agent_steps_sampled': 56520, 'num_agent_steps_trained': 1141760, 'last_target_update_ts': 56520, 'num_target_updates': 4460, 'num_env_steps_sampled_for_evaluation_this_iter': 57431}, 'done': False, 'training_iteration': 501, 'trial_id': 'default', 'date': '2024-10-08_01-55-46', 'timestamp': 1728320146, 'time_this_iter_s': 1.7139627933502197, 'time_total_s': 1937.8597495555878, 'pid': 25604, 'hostname': 'OMEN-45L', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ddp_kwargs': {}, 'torch_skip_nan_gradie ...
# 501th iteration done
# 502th iteration done
# 503th iteration done
# 504th iteration done
# 505th iteration done
# 506th iteration done
# 507th iteration done
# 508th iteration done
# 509th iteration done
# 510th iteration done
# 511th iteration done
# 512th iteration done
# 513th iteration done
# 514th iteration done
# 515th iteration done
# 516th iteration done
# 517th iteration done
# 518th iteration done
# 519th iteration done
# 520th iteration done
# 521th iteration done
# 522th iteration done
# 523th iteration done
# 524th iteration done
# 525th iteration done
# 526th iteration done
# 527th iteration done
# 528th iteration done
# 529th iteration done
# 530th iteration done
# 531th iteration done
# 532th iteration done
# 533th iteration done
# 534th iteration done
# 535th iteration done
# 536th iteration done
# 537th iteration done
# 538th iteration done
# 539th iteration done
# 540th iteration done
# 541th iteration done
# 542th iteration done
# 543th iteration done
# 544th iteration done
# 545th iteration done
# 546th iteration done
# 547th iteration done
# 548th iteration done
# 549th iteration done
# 550th iteration done
# 551th iteration done
# 552th iteration done
# 553th iteration done
# 554th iteration done
# 555th iteration done
# 556th iteration done
# 557th iteration done
# 558th iteration done
# 559th iteration done
# 560th iteration done
# 561th iteration done
# 562th iteration done
# 563th iteration done
# 564th iteration done
# 565th iteration done
# 566th iteration done
# 567th iteration done
# 568th iteration done
# 569th iteration done
# 570th iteration done
# 571th iteration done
# 572th iteration done
# 573th iteration done
# 574th iteration done
# 575th iteration done
# 576th iteration done
# 577th iteration done
# 578th iteration done
# 579th iteration done
# 580th iteration done
# 581th iteration done
# 582th iteration done
# 583th iteration done
# 584th iteration done
# 585th iteration done
# 586th iteration done
# 587th iteration done
# 588th iteration done
# 589th iteration done
# 590th iteration done
# 591th iteration done
# 592th iteration done
# 593th iteration done
# 594th iteration done
# 595th iteration done
# 596th iteration done
# 597th iteration done
# 598th iteration done
# 599th iteration done
# 600th iteration done
# 601th iteration done
# 602th iteration done
# 603th iteration done
# 604th iteration done
# 605th iteration done
# 606th iteration done
# 607th iteration done
# 608th iteration done
# 609th iteration done
# 610th iteration done
# 611th iteration done
# 612th iteration done
# 613th iteration done
# 614th iteration done
# 615th iteration done
# 616th iteration done
# 617th iteration done
# 618th iteration done
# 619th iteration done
# 620th iteration done
# 621th iteration done
# 622th iteration done
# 623th iteration done
# 624th iteration done
# 625th iteration done
# 626th iteration done
# 627th iteration done
# 628th iteration done
# 629th iteration done
# 630th iteration done
# 631th iteration done
# 632th iteration done
# 633th iteration done
# 634th iteration done
# 635th iteration done
# 636th iteration done
# 637th iteration done
# 638th iteration done
# 639th iteration done
# 640th iteration done
# 641th iteration done
# 642th iteration done
# 643th iteration done
# 644th iteration done
# 645th iteration done
# 646th iteration done
# 647th iteration done
# 648th iteration done
# 649th iteration done
# 650th iteration done
# 651th iteration done
# 652th iteration done
# 653th iteration done
# 654th iteration done
# 655th iteration done
# 656th iteration done
# 657th iteration done
# 658th iteration done
# 659th iteration done
# 660th iteration done
# 661th iteration done
# 662th iteration done
# 663th iteration done
# 664th iteration done
# 665th iteration done
# 666th iteration done
# 667th iteration done
# 668th iteration done
# 669th iteration done
# 670th iteration done
# 671th iteration done
# 672th iteration done
# 673th iteration done
# 674th iteration done
# 675th iteration done
# 676th iteration done
# 677th iteration done
# 678th iteration done
# 679th iteration done
# 680th iteration done
# 681th iteration done
# 682th iteration done
# 683th iteration done
# 684th iteration done
# 685th iteration done
# 686th iteration done
# 687th iteration done
# 688th iteration done
# 689th iteration done
# 690th iteration done
# 691th iteration done
# 692th iteration done
# 693th iteration done
# 694th iteration done
# 695th iteration done
# 696th iteration done
# 697th iteration done
# 698th iteration done
# 699th iteration done
# 700th iteration done
# 701th iteration done
# 702th iteration done
# 703th iteration done
# 704th iteration done
# 705th iteration done
# 706th iteration done
# 707th iteration done
# 708th iteration done
# 709th iteration done
# 710th iteration done
# 711th iteration done
# 712th iteration done
# 713th iteration done
# 714th iteration done
# 715th iteration done
# 716th iteration done
# 717th iteration done
# 718th iteration done
# 719th iteration done
# 720th iteration done
# 721th iteration done
# 722th iteration done
# 723th iteration done
# 724th iteration done
# 725th iteration done
# 726th iteration done
# 727th iteration done
# 728th iteration done
# 729th iteration done
# 730th iteration done
# 731th iteration done
# 732th iteration done
# 733th iteration done
# 734th iteration done
# 735th iteration done
# 736th iteration done
# 737th iteration done
# 738th iteration done
# 739th iteration done
# 740th iteration done
# 741th iteration done
# 742th iteration done
# 743th iteration done
# 744th iteration done
# 745th iteration done
# 746th iteration done
# 747th iteration done
# 748th iteration done
# 749th iteration done
# 750th iteration done
# 751th iteration done
# 752th iteration done
# 753th iteration done
# 754th iteration done
# 755th iteration done
# 756th iteration done
# 757th iteration done
# 758th iteration done
# 759th iteration done
# 760th iteration done
# 761th iteration done
# 762th iteration done
# 763th iteration done
# 764th iteration done
# 765th iteration done
# 766th iteration done
# 767th iteration done
# 768th iteration done
# 769th iteration done
# 770th iteration done
# 771th iteration done
# 772th iteration done
# 773th iteration done
# 774th iteration done
# 775th iteration done
# 776th iteration done
# 777th iteration done
# 778th iteration done
# 779th iteration done
# 780th iteration done
# 781th iteration done
# 782th iteration done
# 783th iteration done
# 784th iteration done
# 785th iteration done
# 786th iteration done
# 787th iteration done
# 788th iteration done
# 789th iteration done
# 790th iteration done
# 791th iteration done
# 792th iteration done
# 793th iteration done
# 794th iteration done
# 795th iteration done
# 796th iteration done
# 797th iteration done
# 798th iteration done
# 799th iteration done
# 800th iteration done
# 801th iteration done
# 802th iteration done
# 803th iteration done
# 804th iteration done
# 805th iteration done
# 806th iteration done
# 807th iteration done
# 808th iteration done
# 809th iteration done
# 810th iteration done
# 811th iteration done
# 812th iteration done
# 813th iteration done
# 814th iteration done
# 815th iteration done
# 816th iteration done
# 817th iteration done
# 818th iteration done
# 819th iteration done
# 820th iteration done
# 821th iteration done
# 822th iteration done
# 823th iteration done
# 824th iteration done
# 825th iteration done
# 826th iteration done
# 827th iteration done
# 828th iteration done
# 829th iteration done
# 830th iteration done
# 831th iteration done
# 832th iteration done
# 833th iteration done
# 834th iteration done
# 835th iteration done
# 836th iteration done
# 837th iteration done
# 838th iteration done
# 839th iteration done
# 840th iteration done
# 841th iteration done
# 842th iteration done
# 843th iteration done
# 844th iteration done
# 845th iteration done
# 846th iteration done
# 847th iteration done
# 848th iteration done
# 849th iteration done
# 850th iteration done
# 851th iteration done
# 852th iteration done
# 853th iteration done
# 854th iteration done
# 855th iteration done
# 856th iteration done
# 857th iteration done
# 858th iteration done
# 859th iteration done
# 860th iteration done
# 861th iteration done
# 862th iteration done
# 863th iteration done
# 864th iteration done
# 865th iteration done
# 866th iteration done
# 867th iteration done
# 868th iteration done
# 869th iteration done
# 870th iteration done
# 871th iteration done
# 872th iteration done
# 873th iteration done
# 874th iteration done
# 875th iteration done
# 876th iteration done
# 877th iteration done
# 878th iteration done
# 879th iteration done
# 880th iteration done
# 881th iteration done
# 882th iteration done
# 883th iteration done
# 884th iteration done
# 885th iteration done
# 886th iteration done
# 887th iteration done
# 888th iteration done
# 889th iteration done
# 890th iteration done
# 891th iteration done
# 892th iteration done
# 893th iteration done
# 894th iteration done
# 895th iteration done
# 896th iteration done
# 897th iteration done
# 898th iteration done
# 899th iteration done
# 900th iteration done
# 901th iteration done
# 902th iteration done
# 903th iteration done
# 904th iteration done
# 905th iteration done
# 906th iteration done
# 907th iteration done
# 908th iteration done
# 909th iteration done
# 910th iteration done
# 911th iteration done
# 912th iteration done
# 913th iteration done
# 914th iteration done
# 915th iteration done
# 916th iteration done
# 917th iteration done
# 918th iteration done
# 919th iteration done
# 920th iteration done
# 921th iteration done
# 922th iteration done
# 923th iteration done
# 924th iteration done
# 925th iteration done
# 926th iteration done
# 927th iteration done
# 928th iteration done
# 929th iteration done
# 930th iteration done
# 931th iteration done
# 932th iteration done
# 933th iteration done
# 934th iteration done
# 935th iteration done
# 936th iteration done
# 937th iteration done
# 938th iteration done
# 939th iteration done
# 940th iteration done
# 941th iteration done
# 942th iteration done
# 943th iteration done
# 944th iteration done
# 945th iteration done
# 946th iteration done
# 947th iteration done
# 948th iteration done
# 949th iteration done
# 950th iteration done
# 951th iteration done
# 952th iteration done
# 953th iteration done
# 954th iteration done
# 955th iteration done
# 956th iteration done
# 957th iteration done
# 958th iteration done
# 959th iteration done
# 960th iteration done
# 961th iteration done
# 962th iteration done
# 963th iteration done
# 964th iteration done
# 965th iteration done
# 966th iteration done
# 967th iteration done
# 968th iteration done
# 969th iteration done
# 970th iteration done
# 971th iteration done
# 972th iteration done
# 973th iteration done
# 974th iteration done
# 975th iteration done
# 976th iteration done
# 977th iteration done
# 978th iteration done
# 979th iteration done
# 980th iteration done
# 981th iteration done
# 982th iteration done
# 983th iteration done
# 984th iteration done
# 985th iteration done
# 986th iteration done
# 987th iteration done
# 988th iteration done
# 989th iteration done
# 990th iteration done
# 991th iteration done
# 992th iteration done
# 993th iteration done
# 994th iteration done
# 995th iteration done
# 996th iteration done
# 997th iteration done
# 998th iteration done
# 999th iteration done
# 1000th iteration done
# Checkpoint saved in directory TrainingResult(checkpoint=Checkpoint(filesystem=local, path=obstacle_512x5_2), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'actor_loss': -11.768138885498047, 'critic_loss': 0.03290530666708946, 'alpha_loss': -59.904415130615234, 'alpha_value': 0.06888917, 'log_alpha_value': -2.6752563, 'target_entropy': -14.0, 'policy_t': 0.027046704664826393, 'mean_q': 11.148172378540039, 'max_q': 12.437398910522461, 'min_q': 9.510109901428223}, 'model': {}, 'num_grad_updates_lifetime': 8960.0, 'diff_num_grad_updates_vs_sampler_policy': 8959.0, 'td_error': array([0.26258612, 0.1858244 , 0.15419626, 0.49038458, 1.0278931 ,
#        0.14297009, 0.1822238 , 1.6217089 , 0.27124834, 0.81017256,
#        0.52339983, 0.60951424, 0.97970486, 0.341259  , 0.6701889 ,
#        0.79487133, 0.16589546, 0.3073721 , 0.5552273 , 0.55793905,
#        0.83039904, 0.30913973, 0.41355038, 0.30393744, 0.15777874,
#        0.77416277, 2.0294557 , 0.42417145, 1.214025  , 1.4121675 ,
#        0.2739854 , 0.32331133, 0.6123781 , 0.52416563, 0.2677617 ,
#        0.6472583 , 0.0980978 , 0.22135973, 0.21408558, 0.58022594,
#        0.62821674, 0.92260695, 0.25091648, 0.14594984, 1.4507408 ,
#        1.0322032 , 0.14364672, 0.27825403, 0.34687614, 0.05614805,
#        0.26284885, 0.95728683, 0.67144966, 0.5637021 , 0.46011734,
#        0.42120504, 0.5710273 , 0.5115752 , 0.2862563 , 0.92879343,
#        0.32895565], dtype=float32), 'mean_td_error': 0.5649096369743347}}, 'num_env_steps_sampled': 110520, 'num_env_steps_trained': 2293760, 'num_agent_steps_sampled': 110520, 'num_agent_steps_trained': 2293760, 'last_target_update_ts': 110520, 'num_target_updates': 8960, 'num_env_steps_sampled_for_evaluation_this_iter': 60000}, 'env_runners': {'episode_reward_max': 843.0631094631747, 'episode_reward_min': -173.66449401171926, 'episode_reward_mean': 338.32588828540884, 'episode_len_mean': 5579.714285714285, 'episode_media': {}, 'episodes_timesteps_total': 78116, 'policy_reward_min': {'default_policy': -173.66449401171926}, 'policy_reward_max': {'default_policy': 843.0631094631747}, 'policy_reward_mean': {'default_policy': 338.32588828540884}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [170.4963788648225, 226.00538271898725, 670.9201774437574, 659.1816358916144, 497.2037592109242, -173.66449401171926, 182.11174491065634, 387.7977877248513, 565.3110034243749, 110.36419270566766, 843.0631094631747, 562.2606263395969, 16.05109679662177, 19.460034512392408], 'episode_lengths': [3055, 3061, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000], 'policy_default_policy_reward': [170.4963788648225, 226.00538271898725, 670.9201774437574, 659.1816358916144, 497.2037592109242, -173.66449401171926, 182.11174491065634, 387.7977877248513, 565.3110034243749, 110.36419270566766, 843.0631094631747, 562.2606263395969, 16.05109679662177, 19.460034512392408]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.8812971018441225, 'mean_inference_ms': 16.518710337932777, 'mean_action_processing_ms': 0.2096323377256625, 'mean_env_wait_ms': 2.52833608581507, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0, 'StateBufferConnector_ms': 0.0, 'ViewRequirementAgentConnector_ms': 0.0510096549987793}, 'num_episodes': 0, 'episode_return_max': 843.0631094631747, 'episode_return_min': -173.66449401171926, 'episode_return_mean': 338.32588828540884, 'episodes_this_iter': 0}, 'num_healthy_workers': 12, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 110520, 'num_agent_steps_trained': 2293760, 'num_env_steps_sampled': 110520, 'num_env_steps_trained': 2293760, 'num_env_steps_sampled_this_iter': 108, 'num_env_steps_trained_this_iter': 2304, 'num_env_steps_sampled_throughput_per_sec': 62.60212323661327, 'num_env_steps_trained_throughput_per_sec': 1335.511962381083, 'timesteps_total': 110520, 'num_env_steps_sampled_lifetime': 110520, 'num_agent_steps_sampled_lifetime': 110520, 'num_steps_trained_this_iter': 2304, 'agent_timesteps_total': 110520, 'timers': {'training_iteration_time_ms': 1684.27, 'restore_workers_time_ms': 0.0, 'training_step_time_ms': 191.522, 'sample_time_ms': 58.787, 'load_time_ms': 0.559, 'load_throughput': 458237.378, 'learn_time_ms': 14.786, 'learn_throughput': 17313.39, 'synch_weights_time_ms': 32.394, 'restore_eval_workers_time_ms': 0.0, 'evaluation_iteration_time_ms': 209817.647, 'evaluation_iteration_throughput': 274.809}, 'counters': {'num_env_steps_sampled': 110520, 'num_env_steps_trained': 2293760, 'num_agent_steps_sampled': 110520, 'num_agent_steps_trained': 2293760, 'last_target_update_ts': 110520, 'num_target_updates': 8960, 'num_env_steps_sampled_for_evaluation_this_iter': 60000}, 'done': False, 'training_iteration': 1001, 'trial_id': 'default', 'date': '2024-10-08_02-27-28', 'timestamp': 1728322048, 'time_this_iter_s': 1.7714605331420898, 'time_total_s': 3830.1973061561584, 'pid': 25604, 'hostname': 'OMEN-45L', 'node_ip': '127.0.0.1', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log ...
# 1001th iteration done
# 1002th iteration done
# 1003th iteration done
# 1004th iteration done
# 1005th iteration done
# 1006th iteration done
# 1007th iteration done
# 1008th iteration done
# 1009th iteration done
# 1010th iteration done
# 1011th iteration done
# 1012th iteration done
# 1013th iteration done
# 1014th iteration done
# 1015th iteration done
# 1016th iteration done
# 1017th iteration done
# 1018th iteration done
# 1019th iteration done
# 1020th iteration done
# 1021th iteration done
# 1022th iteration done
# 1023th iteration done
# 1024th iteration done
# 1025th iteration done
# 1026th iteration done
# 1027th iteration done
# 1028th iteration done
# 1029th iteration done
# 1030th iteration done
# 1031th iteration done
# 1032th iteration done
# 1033th iteration done
# 1034th iteration done
# 1035th iteration done
# 1036th iteration done
# 1037th iteration done
# 1038th iteration done
# 1039th iteration done
# 1040th iteration done
# 1041th iteration done
# 1042th iteration done
# 1043th iteration done
# 1044th iteration done
# 1045th iteration done
# 1046th iteration done
# 1047th iteration done
# 1048th iteration done
# 1049th iteration done
# 1050th iteration done
# 1051th iteration done
# 1052th iteration done
# 1053th iteration done
# 1054th iteration done
# 1055th iteration done
# 1056th iteration done
# 1057th iteration done
# 1058th iteration done
# 1059th iteration done
# 1060th iteration done
# 1061th iteration done
# 1062th iteration done
# 1063th iteration done
# 1064th iteration done
# 1065th iteration done
# 1066th iteration done
# 1067th iteration done
# 1068th iteration done
# 1069th iteration done
# 1070th iteration done
# 1071th iteration done
# 1072th iteration done
# 1073th iteration done
# 1074th iteration done
# 1075th iteration done
# 1076th iteration done
# 1077th iteration done
# 1078th iteration done
# 1079th iteration done
# 1080th iteration done
# 1081th iteration done
# 1082th iteration done
# 1083th iteration done
# 1084th iteration done
# 1085th iteration done
# 1086th iteration done
# 1087th iteration done
# 1088th iteration done
# 1089th iteration done
# 1090th iteration done
# 1091th iteration done
# 1092th iteration done
# 1093th iteration done
# 1094th iteration done
# 1095th iteration done
# 1096th iteration done
# 1097th iteration done
# 1098th iteration done
# 9867th iteration done
# 9868th iteration done
# 9869th iteration done
# 9870th iteration done
# 9871th iteration done
# 9872th iteration done
# 9873th iteration done
# 9874th iteration done
# 9875th iteration done
# 9876th iteration done
# 9877th iteration done
# 9878th iteration done
# 9879th iteration done
# 9880th iteration done
# 9881th iteration done
# 9882th iteration done
# 9883th iteration done
# 9884th iteration done
# 9885th iteration done
# 9886th iteration done
# 9887th iteration done
# 9888th iteration done
# 9889th iteration done
# 9890th iteration done
# 9891th iteration done
# 9892th iteration done
# 9893th iteration done
# 9894th iteration done
# 9895th iteration done
# 9896th iteration done
# 9897th iteration done
# 9898th iteration done
# 9899th iteration done
# 9900th iteration done
# 9901th iteration done
# 9902th iteration done
# 9903th iteration done
# 9904th iteration done
# 9905th iteration done
# 9906th iteration done
# 9907th iteration done
# 9908th iteration done
# 9909th iteration done
# 9910th iteration done
# 9911th iteration done
# 9912th iteration done
# 9913th iteration done
# 9914th iteration done
# 9915th iteration done
# 9916th iteration done
# 9917th iteration done
# 9918th iteration done
# 9919th iteration done
# 9920th iteration done
# 9921th iteration done
# 9922th iteration done
# 9923th iteration done
# 9924th iteration done
# 9925th iteration done
# 9926th iteration done
# 9927th iteration done
# 9928th iteration done
# 9929th iteration done
# 9930th iteration done
# 9931th iteration done
# 9932th iteration done
# 9933th iteration done
# 9934th iteration done
# 9935th iteration done
# 9936th iteration done
# 9937th iteration done
# 9938th iteration done
# 9939th iteration done
# 9940th iteration done
# 9941th iteration done
# 9942th iteration done
# 9943th iteration done
# 9944th iteration done
# 9945th iteration done
# 9946th iteration done
# 9947th iteration done
# 9948th iteration done
# 9949th iteration done
# 9950th iteration done
# 9951th iteration done
# 9952th iteration done
# 9953th iteration done
# 9954th iteration done
# 9955th iteration done
# 9956th iteration done
# 9957th iteration done
# 9958th iteration done
# 9959th iteration done
# 9960th iteration done
# 9961th iteration done
# 9962th iteration done
# 9963th iteration done
# 9964th iteration done
# 9965th iteration done
# 9966th iteration done
# 9967th iteration done
# 9968th iteration done
# 9969th iteration done
# 9970th iteration done
# 9971th iteration done
# 9972th iteration done
# 9973th iteration done
# 9974th iteration done
# 9975th iteration done
# 9976th iteration done
# 9977th iteration done
# 9978th iteration done
# 9979th iteration done
# 9980th iteration done
# 9981th iteration done
# 9982th iteration done
# 9983th iteration done
# 9984th iteration done
# 9985th iteration done
# 9986th iteration done
# 9987th iteration done
# 9988th iteration done
# 9989th iteration done
# 9990th iteration done
# 9991th iteration done
# 9992th iteration done
# 9993th iteration done
# 9994th iteration done
# 9995th iteration done
# 9996th iteration done
# 9997th iteration done
# 9998th iteration done
# 9999th iteration done
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=obstacle_512x5_final), metrics={'evaluation': {'env_runners': {'episode_reward_max': 1100.4761059042294, 'episode_reward_min': -1164.0199099595084, 'episode_reward_mean': -162.85164048081896, 'episode_len_mean': 4838.3, 'episode_media': {}, 'episodes_timesteps_total': 48383, 'policy_reward_min': {'default_policy': -1164.0199099595084}, 'policy_reward_max': {'default_policy': 1100.4761059042294}, 'policy_reward_mean': {'default_policy': -162.85164048081896}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-325.810307132228, -157.97682299638225, -555.7614074020597, 1100.4761059042294, -530.644751535976, -34.57927997755037, 132.74620809464105, -653.0706124159611, -1164.0199099595084, 560.124372612606], 'episode_lengths': [6000, 306, 6000, 6000, 6000, 77, 6000, 6000, 6000, 6000], 'policy_default_policy_reward': [-325.810307132228, -157.97682299638225, -555.7614074020597, 1100.4761059042294, -530.644751535976, -34.57927997755037, 132.74620809464105, -653.0706124159611, -1164.0199099595084, 560.124372612606]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.20057049462692703, 'mean_inference_ms': 1.7046671779540024, 'mean_action_processing_ms': 0.11006598033288365, 'mean_env_wait_ms': 1.5182030481629085, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0, 'StateBufferConnector_ms': 0.0, 'ViewRequirementAgentConnector_ms': 0.12537240982055664}, 'num_episodes': 10, 'episode_return_max': 1100.4761059042294, 'episode_return_min': -1164.0199099595084, 'episode_return_mean': -162.85164048081896, 'episodes_this_iter': 10}, 'num_agent_steps_sampled_this_iter': 48383, 'num_env_steps_sampled_this_iter': 48383, 'timesteps_this_iter': 48383, 'num_healthy_workers': 0, 'num_in_flight_async_reqs': 0, 'num_remote_worker_restarts': 0}, 'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'actor_loss': 0.27675724029541016, 'critic_loss': 0.06764937192201614, 'alpha_loss': -3.779694080352783, 'alpha_value': 0.004219927, 'log_alpha_value': -5.4679375, 'target_entropy': -14.0, 'policy_t': 0.09103036671876907, 'mean_q': -0.13199950754642487, 'max_q': 5.461430549621582, 'min_q': -4.215669631958008}, 'model': {}, 'num_grad_updates_lifetime': 89951.0, 'diff_num_grad_updates_vs_sampler_policy': 89950.0, 'td_error': array([0.5866977 , 0.9517125 , 0.03305902, 3.670938  , 0.23446138,
#        0.698534  , 1.638942  , 1.2750306 , 2.8091373 , 1.6885684 ,
#        1.4790491 , 2.700985  , 2.2518802 , 1.7853383 , 0.43674576,
#        0.46524274, 0.8706211 , 0.15019268, 0.26781023, 0.3483448 ,
#        0.8473464 , 1.1323762 , 0.21541855, 1.9082712 , 2.5792193 ,
#        0.6641675 , 1.0925382 , 0.26158535, 0.5327703 , 0.41872635,
#        1.069052  , 1.5536426 , 1.7361053 , 1.5690956 , 1.1544194 ,
#        0.4344883 , 0.9189999 , 0.3046037 , 1.0501328 , 4.367459  ,
#        2.856913  , 1.3382108 , 0.6014892 , 0.73309326, 1.2016213 ,
#        0.46486878, 1.2066513 , 1.1112832 , 0.89032894, 0.8971981 ,
#        1.2612514 , 0.71475077, 1.7924025 , 0.53858364, 0.19969642,
#        0.07931948, 0.92283463, 0.27337778, 0.7776155 , 0.4102193 ,
#        0.357978  , 0.23219043, 4.4937806 , 2.4188592 , 1.361923  ,
#        0.62790483, 0.19310957, 2.65934   , 0.25970924, 0.14031786,
#        0.22721177, 0.8578654 , 0.7316207 , 0.76951754, 0.541427  ,
#        4.5451913 , 0.74074423, 5.3869014 , 0.9462837 , 3.8138402 ,
#        1.887923  , 0.4530548 , 1.0033822 , 1.2086846 , 0.4328871 ,
#        0.22609425, 1.7407166 , 0.7927966 , 3.9900658 , 0.20863402,
#        0.55223894, 0.65550005, 0.31577408, 1.7383184 , 0.9497131 ,
#        0.27664053, 0.50784755, 2.0173628 , 0.4006577 , 0.28036213,
#        1.0064507 , 1.424362  , 0.52564144, 3.5562358 , 0.6606167 ,
#        1.1806681 , 0.8375662 , 0.5927422 , 0.9504445 , 0.35840583,
#        1.0136062 , 0.29899776, 0.53089476, 1.2557474 , 1.84235   ,
#        2.0297174 , 2.3443213 , 2.464387  , 0.1094934 , 0.2610621 ,
#        1.2818131 , 3.8191793 , 1.6933761 , 0.74476963, 1.4345689 ,
#        0.2345072 , 0.14768624, 0.68804616, 0.05574054, 0.49487448,
#        1.3630722 , 0.3055277 , 0.24081373, 0.2263138 , 0.49246407,
#        0.8410868 , 0.39180434, 1.6212158 , 1.3663557 , 0.36342287,
#        3.3302262 , 0.16647184, 1.0577451 , 0.3286831 , 0.30836448,
#        0.44164753, 0.56070775, 0.27956653, 1.5161412 , 0.3588789 ,
#        1.4532032 , 0.5133469 , 2.1355886 , 0.14404303, 0.5407288 ,
#        0.06275176, 0.5633537 , 3.0330935 , 0.77213824, 0.18736911,
#        1.2973143 , 2.7971458 , 0.7923303 , 0.19871497, 0.9160256 ,
#        0.44317165, 0.23989183, 0.5518907 , 2.4213777 , 0.5358887 ,
#        0.1134007 , 1.7803106 , 4.2145677 , 0.25743246, 1.6463357 ,
#        0.2608567 , 0.697815  , 0.5839673 , 1.637192  , 0.5017103 ,
#        2.9010706 , 0.31511974, 1.1214284 , 0.6218265 , 0.30668283,
#        2.4454317 , 0.5999179 , 0.38846278, 0.12576747, 0.35329458,
#        6.0896845 , 0.3266263 , 1.0857904 , 0.47995225, 5.964934  ,
#        0.96885896, 0.3194222 , 3.623004  , 1.3334599 , 0.6770625 ,
#        0.9319499 , 1.708821  , 0.6882783 , 1.3464763 , 2.2120047 ,
#        0.36537263, 0.6664257 , 0.9272349 , 0.60682005, 0.21566233,
#        0.9823    , 0.9311408 , 0.56554496, 0.9851729 , 0.6070717 ,
#        0.90643847, 2.2142584 , 0.19971418, 1.46452   , 3.2479124 ,
#        1.7611016 , 0.6310542 , 0.25571132, 1.3899608 , 0.34534147,
#        0.5876105 , 0.08554107, 0.16145802, 0.78699577, 0.38007155,
#        0.75300527, 1.0716343 , 1.1915948 , 3.3535786 , 0.24779676,
#        0.72868025, 0.85708034, 1.19804   , 2.6710508 , 0.50501454,
#        2.2611907 , 0.16530704, 0.04888624, 0.323923  , 1.2175243 ,
#        0.94527274, 0.18493187, 4.6693735 , 0.50175273, 0.89916414,
#        1.773236  , 0.48654222, 0.36637142, 2.4095035 , 0.65159744,
#        0.11304897], dtype=float32), 'mean_td_error': 1.1166499853134155}}, 'num_env_steps_sampled': 1082412, 'num_env_steps_trained': 23027456, 'num_agent_steps_sampled': 1082412, 'num_agent_steps_trained': 23027456, 'last_target_update_ts': 1082412, 'num_target_updates': 89951, 'num_env_steps_sampled_for_evaluation_this_iter': 48383}, 'env_runners': {'episode_reward_max': 5157.490281846596, 'episode_reward_min': -1058.8403004571173, 'episode_reward_mean': -73.87954841782401, 'episode_len_mean': 5431.18, 'episode_media': {}, 'episodes_timesteps_total': 543118, 'policy_reward_min': {'default_policy': -1058.8403004571173}, 'policy_reward_max': {'default_policy': 5157.490281846596}, 'policy_reward_mean': {'default_policy': -73.87954841782401}, 'custom_metrics': {}, 'hist_stats': {'episode_reward':
# %%
from ray.rllib.core.rl_module import RLModule
import pathlib
import torch
import numpy as np
import gymnasium as gym
from horcrux_terrain_v1.envs import SandWorld
import time

algo = Algorithm.from_checkpoint("./SAC/GD/SAC_512x5_GD_final")

# %%
# env = gym.make("horcrux_terrain_v1/plane-v1", 
#                terminate_when_unhealthy = False, 
#                render_mode = "human", 
#             #    render_camera_name = 'ceiling', 
#                use_gait = True,
#                gait_params = (30,30,40,40,0),
#                **env_config,
#                ) 

# obs, info = env.reset()

# algo.get_policy().action_connectors

# %%
# env = gym.make("horcrux_terrain_v1/sand-v1", 
#                terminate_when_unhealthy = False, 
#                render_mode = "human", 
#             #    render_camera_name = 'ceiling', 
#                use_gait = True,
#                gait_params = (30,30,40,40,0),
#                **env_config,
#                ) 

env = gym.make("horcrux_terrain_v1/pipe-v1", 
               terminate_when_unhealthy = False, 
               render_mode = "human", 
            #    render_camera_name = 'ceiling', 
               use_gait = True,
               gait_params = (30,30,15,15,0),
               **env_config,
               ) 

for j in range(5):
   episode_return = 0
   terminated = truncated = False

   obs, info = env.reset()


   for i in range(3000):
      action = algo.compute_single_action(obs, explore=False)
      
      obs, reward, terminated, truncated, info = env.step(action)
      
      prev_a = action

      if terminated:
         print("terminated")

      episode_return += reward

   print(f"Reached episode return of {episode_return}.")

env.close()
# Out:
# Exception ignored in: <function WindowViewer.__del__ at 0x000001CA21A92C00>
# Traceback (most recent call last):
#   File "c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py", line 335, in __del__
#     self.free()
#   File "c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py", line 330, in free
#     glfw.destroy_window(self.window)
#   File "c:\Users\doore\anaconda3\envs\gdtor\Lib\site-packages\glfw\__init__.py", line 1279, in destroy_window
#     window_addr = ctypes.cast(ctypes.pointer(window),
#                               ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: _type_ must have storage info
# Reached episode return of 316.2599167434524.
# Reached episode return of 365.5421221327736.
# Reached episode return of -179.01323955833232.
# Reached episode return of -234.56127774436388.
# Reached episode return of -203.47581582285864.

# %% [markdown]
# 환경에서 학습된 Policy 테스트하기 (PPO 알고리즘 사용)

# %%
import pathlib
import torch
import numpy as np
import gymnasium as gym
from horcrux_terrain_v1.envs import SandWorld
from ray.rllib.algorithms.algorithm import Algorithm
import time

env = gym.make("horcrux_terrain_v1/plane-v1", 
               terminate_when_unhealthy = False, 
               render_mode = "human", 
            #    render_camera_name = 'ceiling', 
               use_gait = True,
               gait_params = (30,30,40,40,0),
               **env_config,
               ) 

for j in range(10):
   episode_return = 0
   terminated = truncated = False

   obs, info = env.reset()

   init_state = state = [np.zeros([4096], np.float32) for _ in range(200)]
   prev_action = np.zeros((14), np.float32)
   for i in range(1000):

      a, init_state = algo.compute_single_action(observation= obs, state=init_state, prev_action=prev_action,policy_id="default_policy")
      
      obs, reward, terminated, truncated, info = env.step(action)

      prev_action = a
      if terminated:
         print("terminated")

      episode_return += reward

   print(f"Reached episode return of {episode_return}.")

env.close()
